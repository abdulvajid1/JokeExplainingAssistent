# %%
from langchain.prompts import PromptTemplate , ChatPromptTemplate
from langchain.chat_models import init_chat_model
from langchain_core.output_parsers import StrOutputParser


import torch
from dotenv import load_dotenv
load_dotenv()
import os

# %%
assert os.environ['GOOGLE_API_KEY'], "Api key is missing"

# %%
chat_llm = init_chat_model(model='gemini-2.0-flash', model_provider='google_genai')
chat_llm.invoke('hai, how are you')
# Out:
# AIMessage(content='I am doing well, thank you for asking! How are you today?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--8ebf452b-cdd5-40bb-b9c8-afb9ab8402a6-0', usage_metadata={'input_tokens': 5, 'output_tokens': 16, 'total_tokens': 21, 'input_token_details': {'cache_read': 0}})

# %%
system_prompt_template ="""You are AI assistent who explain joke provided by user, what does it mean and where does it come from in which context.
You also tell if the joke is based on any special person or a group.
You should explain what is the core idea behind the joke and why it is considerd to be joke.
Explain what is it based on like , it is racial joke ,or any other related."""

# %%
chat_prompt_template = ChatPromptTemplate(
    messages= [
        ('system', system_prompt_template),
        ('user', '{joke}')
    ]
)

# %%
output_parser = StrOutputParser()

# %%
chain = chat_prompt_template | chat_llm | output_parser

# %%
print(chain.invoke('your mama is too ugly she need to use specs on her passport photo'))
# Out:
# Okay, let's break down this joke:
#
# *   **Type of Joke:** This is a "yo mama" joke, which falls under the category of insult humor. These jokes are designed to be playful insults directed at the target's mother.
#
# *   **Core Idea:** The core idea is that the target's mother is so ugly that even official documents (like a passport) require her to wear glasses to make her appearance acceptable.
#
# *   **Why it's considered a joke:** The humor comes from the exaggeration and absurdity of the insult. The idea that someone's ugliness is so extreme it affects their passport photo is ridiculous.
#
# *   **Context and Meaning:** "Specs" is a colloquial term for "spectacles" or eyeglasses. The joke implies that the mother's appearance is so visually jarring that it needs to be corrected or filtered, even for a standard identification photo.
#
# *   **Based On:** This joke relies on a stereotype of ugliness and uses it in a hyperbolic way.
#
# In summary, the joke uses hyperbole to suggest extreme ugliness, making the situation absurd and, therefore, humorous (at least to some).
